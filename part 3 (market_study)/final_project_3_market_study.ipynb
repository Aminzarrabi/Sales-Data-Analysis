# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import time
from datetime import datetime

# %%
df = pd.read_csv('preprocessed_sales.csv')
df
# Out:
#         InvoiceNumber ProductCode                          ProductName  \
# 0              489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1              489434      79323P                   PINK CHERRY LIGHTS
# 2              489434      79323W                  WHITE CHERRY LIGHTS
# 3              489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4              489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...               ...         ...                                  ...
# 400911         538171       22271                 FELTCRAFT DOLL ROSIE
# 400912         538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 400913         538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 400914         538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 400915         538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity          InvoiceDate  UnitPrice  CustomerId         Country
# ...

# %%
df = df.drop(df[df.Country =='United Kingdom'].index)
df['ProductPrice'] = df['Quantity'] * df['UnitPrice']
customer_count = df.groupby('Country')['CustomerId'].nunique()
sales_sum = df.groupby('Country')['ProductPrice'].sum()
dff = pd.DataFrame()
dff['CC'] = customer_count
dff['SA'] = sales_sum
dff['qCC'] = dff['CC'].quantile(0.75)
dff['qSA'] = dff['SA'].quantile(0.75)

red_groups = dff[(dff['CC'] > qCC) & (dff['SA'] > qSA)]
blue_groups = dff[(dff['CC'] > qCC) & (dff['SA'] < qSA)]
green_groups = dff[(dff['CC'] < qCC) & (dff['SA'] > qSA)]
cyan_groups = dff[(dff['CC'] < qCC) & (dff['SA'] < qSA)]

plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(red_groups['SA'], red_groups['CC'], color='red', label='Highest customer & revenue',marker = 'o',s = 20)
ax.scatter(blue_groups['SA'], blue_groups['CC'], color='blue', label='High customer & low revenue',marker = 'o',s = 20)
ax.scatter(green_groups['SA'], green_groups['CC'], color='green', label='High revenue & low customer',marker = 'o',s = 20)
ax.scatter(cyan_groups['SA'], cyan_groups['CC'], color='cyan', label='Low customer & revenue',marker = 'o',s = 20)



for country in countries_to_label:
    if country in dff.index: 
        ax.text(dff['SA'][dff.index[dff.index == country][0]], dff['CC'][dff.index[dff.index == country][0]] + 0.5, country, fontsize=15)



ax.set_title('Market Study', fontsize=18)
ax.set_xlabel('Sales amount', fontsize=16)
ax.set_ylabel('Number of customers', fontsize=16)
ax.legend(title="Group",frameon=True,title_fontsize=16,facecolor='silver',fontsize=14)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       8 dff['qCC'] = dff['CC'].quantile(0.75)
#       9 dff['qSA'] = dff['SA'].quantile(0.75)
# ---> 11 red_groups = dff[(dff['CC'] > qCC) & (dff['SA'] > qSA)]
#      12 blue_groups = dff[(dff['CC'] > qCC) & (dff['SA'] < qSA)]
#      13 green_groups = dff[(dff['CC'] < qCC) & (dff['SA'] > qSA)]
#
# NameError: name 'qCC' is not defined
